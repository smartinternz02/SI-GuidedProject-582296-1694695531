# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[4.7,1.8,1.7,1.7,'high'],
                   [4.5,1.4,1.8,0.9,'high'],
                   [4.7,1.8,1.9,1.3,'high'],
                   [4.5,1.8,1.7,1.3,'medium'],
                   [4.3,1.6,1.9,1.7,'medium'],
                   [4.3,1.4,1.7,0.9,'low'],
                   [4.5,1.6,1.9,0.9,'very-low'],
                   [4.5,1.4,1.8,1.3,'very-low'],
                   [4.6,1.4,1.8,1.7,'high'],
                   [4.7,1.4,0.9,np.nan,'medium']])

# %%
df.columns=['length','height','width','weight','quality']

# %%
df
# Out:
#    length  height  width  weight   quality
# 0     4.7     1.8    1.7     1.7      high
# 1     4.5     1.4    1.8     0.9      high
# 2     4.7     1.8    1.9     1.3      high
# 3     4.5     1.8    1.7     1.3    medium
# 4     4.3     1.6    1.9     1.7    medium
# 5     4.3     1.4    1.7     0.9       low
# 6     4.5     1.6    1.9     0.9  very-low
# 7     4.5     1.4    1.8     1.3  very-low
# 8     4.6     1.4    1.8     1.7      high
# 9     4.7     1.4    0.9     NaN    medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   length   10 non-null     float64
#  1   height   10 non-null     float64
#  2   width    10 non-null     float64
#  3   weight   9 non-null      float64
#  4   quality  10 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 528.0+ bytes

# %%
df.describe()
# Out:
#           length     height      width   weight
# count  10.000000  10.000000  10.000000  9.00000
# mean    4.530000   1.560000   1.710000  1.30000
# std     0.149443   0.183787   0.296086  0.34641
# min     4.300000   1.400000   0.900000  0.90000
# 25%     4.500000   1.400000   1.700000  0.90000
# 50%     4.500000   1.500000   1.800000  1.30000
# 75%     4.675000   1.750000   1.875000  1.70000
# max     4.700000   1.800000   1.900000  1.70000

# %%
df.loc[4]
# Out:
# length        4.3
# height        1.6
# width         1.9
# weight        1.7
# quality    medium
# Name: 4, dtype: object

# %%
df.isnull().sum()
# Out:
# length     0
# height     0
# width      0
# weight     1
# quality    0
# dtype: int64

# %%
df.weight.median()
# Out:
# 1.3

# %%
df.weight=df.weight.fillna(df.weight.median())

# %%
df
# Out:
#    length  height  width  weight   quality
# 0     4.7     1.8    1.7     1.7      high
# 1     4.5     1.4    1.8     0.9      high
# 2     4.7     1.8    1.9     1.3      high
# 3     4.5     1.8    1.7     1.3    medium
# 4     4.3     1.6    1.9     1.7    medium
# 5     4.3     1.4    1.7     0.9       low
# 6     4.5     1.6    1.9     0.9  very-low
# 7     4.5     1.4    1.8     1.3  very-low
# 8     4.6     1.4    1.8     1.7      high
# 9     4.7     1.4    0.9     1.3    medium
